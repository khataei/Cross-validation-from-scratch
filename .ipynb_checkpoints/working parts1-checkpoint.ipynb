# %%
from pandas import read_csv
import math
import numpy as np
import pandas as pd
initial= read_csv("b.tsv",header=None,sep="\t")
k=3 # number of folds
n=initial.shape[0] # number of total rows
l= math.ceil(n/k) # maximum number of rows in each fold
f=initial.shape[1] # number of features+target
folds= np.empty((k,l,f)) # creating empty folds, we have k fold, each has l rows and f column
folds[:]=np.nan
# if need to shuffle use this:
# suffle them with sklearn 
# from sklearn import utils
# initial=utils.shuffle(initial)
classA= initial.loc[initial[f-1]==0] # the one with 0 in the last column are class A
classB= initial.loc[initial[f-1]==1]
ca=classA.values # convert pandas Data frame to numpy array
cb=classB.values
sizeA=ca.shape[0]
sizeB=cb.shape[0]
for i in range(sizeA): # asigning almost equal number of class A and B to folds
        folds[i%k,i//k,:]=ca[i,:]
sizeT=sizeA+sizeB
for i in range(sizeA,sizeT,1): # we start from sizeA to continue with the next fold, not necceserily the first one
        folds[i%k,i//k,:]=cb[i-sizeA,:]
# Untill here we read the data, devided into k fold, each fold has same number of class A and B
print(folds) # check the results
# Out:
# [[[ 1.  2.  3.  4.  0.]
#   [ 5.  6.  3.  1.  0.]
#   [ 2.  3.  7.  1.  1.]
#   [ 7.  8.  2.  2.  1.]]
#
#  [[ 7.  3.  3.  9.  0.]
#   [ 3.  7.  2.  8.  1.]
#   [ 7.  8.  2.  2.  1.]
#   [ 7.  8.  2.  2.  1.]]
#
#  [[ 2.  5.  1.  0.  0.]
#   [ 5.  6.  4.  6.  1.]
#   [ 7.  8.  2.  2.  1.]
#   [nan nan nan nan nan]]]

# %%
import pandas as pd
for kk in range(k):
    # Convert selected fold , kk, to test and the rest to train
    dfTest=pd.DataFrame(folds[kk,:,:]).dropna().reset_index(drop=True)
    dfTrain= pd.DataFrame(np.delete(folds, kk, axis=0).ravel().reshape((k-1)*l,f)).dropna().reset_index(drop=True)
#     print("{} rd test set is".format(kk))
#     print(dfTest)
# Out:
# 0 rd test set is
#      0    1    2    3    4
# 0  1.0  2.0  3.0  4.0  0.0
# 1  5.0  6.0  3.0  1.0  0.0
# 2  2.0  3.0  7.0  1.0  1.0
# 3  7.0  8.0  2.0  2.0  1.0
# 1 rd test set is
#      0    1    2    3    4
# 0  7.0  3.0  3.0  9.0  0.0
# 1  3.0  7.0  2.0  8.0  1.0
# 2  7.0  8.0  2.0  2.0  1.0
# 3  7.0  8.0  2.0  2.0  1.0
# 2 rd test set is
#      0    1    2    3    4
# 0  2.0  5.0  1.0  0.0  0.0
# 1  5.0  6.0  4.0  6.0  1.0
# 2  7.0  8.0  2.0  2.0  1.0

# %%
# Sorting dfTest and dfTrain based on relative standard deviation, .i.e. std/mean
dfTrain=dfTrain.reindex((dfTrain.loc[:, dfTrain.columns != f-1].std()/dfTrain.mean()).sort_values(ascending=False).index, axis=1)
dfTrain.columns = range(dfTrain.shape[1])# resets the column index
dfTest=dfTest.reindex((dfTest.loc[:, dfTest.columns != f-1].std()/dfTest.mean()).sort_values(ascending=False).index, axis=1)
dfTest.columns = range(dfTest.shape[1])# resets the column index
# After sortin the column usually the index changes so we reset the index
# Out:
#      0    1    2    3    4
# 0  0.0  1.0  2.0  5.0  0.0
# 1  6.0  4.0  5.0  6.0  1.0
# 2  2.0  2.0  7.0  8.0  1.0

# %%
# extracting X_train and X_test, y_train and y_test
X_train=dfTrain.loc[:, dfTrain.columns != f-1]
y_train=dfTrain[f-1]
X_test=dfTest.loc[:, dfTest.columns != f-1]
y_test=dfTest[f-1]
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8, 4)
# (3, 4)
# (8,)
# (3,)

# %%
maxNei=2 # maximum number of neighbours that we try, nei is the number of neighbours
bestScore=0
from sklearn.neighbors import KNeighborsClassifier
for nei in range(1,maxNei):
    neigh = KNeighborsClassifier(n_neighbors=nei)
    neigh.fit(X_train, y_train)
    score=neigh.score(X_test, y_test) # here y_test is equal to y_actual
    if (bestScore<score):
        bestK=nei
        bestScore=score
        bestP=p
print(bestK)
# Out:
# 1

# %% [markdown]
# ## New start
# Now we need to combine feature selection with KNN scoring part.
# p starts from 1 goes to P ( total features =f)

# %%
from pandas import read_csv
import math
import numpy as np
import pandas as pd
initial= read_csv("b.tsv",header=None,sep="\t")
k=3 # number of folds
n=initial.shape[0] # number of total rows
l= math.ceil(n/k) # maximum number of rows in each fold
f=initial.shape[1] # number of features
folds= np.empty((k,l,f)) # creating empty folds, we have k fold, each has l rows and f column
folds[:]=np.nan
# if need to shuffle use this:
# suffle them with sklearn 
# from sklearn import utils
# initial=utils.shuffle(initial)
classA= initial.loc[initial[f-1]==0] # the one with 0 in the last column are class A
classB= initial.loc[initial[f-1]==1]
ca=classA.values # convert pandas Data frame to numpy array
cb=classB.values
sizeA=ca.shape[0]
sizeB=cb.shape[0]
for i in range(sizeA): # asigning almost equal number of class A and B to folds
        folds[i%k,i//k,:]=ca[i,:]
sizeT=sizeA+sizeB
for i in range(sizeA,sizeT,1): # we start from sizeA to continue with the next fold, not necceserily the first one
        folds[i%k,i//k,:]=cb[i-sizeA,:]
# Untill here we read the data, devided into k fold, each fold has same number of class A and B
# print(folds) # check the results
#################################################################
import pandas as pd
for kk in range(k):
    #### the following repeats for all k folds
    # Convert the selected fold , kk, to test and train sets
    dfTest=pd.DataFrame(folds[kk,:,:]).dropna().reset_index(drop=True)
    dfTrain= pd.DataFrame(np.delete(folds, kk, axis=0).ravel().reshape((k-1)*l,f)).dropna().reset_index(drop=True)
#     print("{} rd test set is".format(kk)) # just for check
#     print(dfTest)    
    ############  Now for this fold we have test and training data so
    ############  we start by selecting first feature ( the most important one) in the next loop
    ############  and for that we perform KNN several times
    bestScore=0 # setting the best KNN score for start
    bestP=0 # shows a p that has the highest score
    for p in range(0,f-1): # the loop for feature selection
        print("=== for {} features:===".format(p+1))
        # Defining test and training data
        X_train=(dfTrain.loc[:,0:p]) 
        X_test=(dfTest.loc[:,0:p])
        y_train=dfTrain[f-1]
        y_test=dfTest[f-1]
    #     print(X_train) # print to check
    #     print(X_test)
    #     print(y_train)
    #     print(y_test)
        maxNei=3 # maximum number of neighbours that we try, nei is the number of neighbours for KNN that changes from 1 to maxNei
        from sklearn.neighbors import KNeighborsClassifier
        for nei in range(1,maxNei):
            print("---- Performing KNN, {} is the number of neighbours:----".format(nei))
            neigh = KNeighborsClassifier(n_neighbors=nei)
            neigh.fit(X_train, y_train)
            score=neigh.score(X_test, y_test) # here y_test is equal to y_actual
            print("Best score untill now:",bestScore)
            print("score difference {(newscore-bestScore)/newscore)} is",((score-bestScore)/score)," And current number of neighbours is", nei)
            if (((score-bestScore)/score)>0.1): # a threshold that if the score improves significantly we update old p and nei
                bestK=nei # we have a new bestK, which is number of neghbours
                bestScore=score
                bestP=p
                print("New bestP:",bestP, "    and best K is:---->",nei," New best score:",bestScore)
            print("-------End of this KNN loop-----")
        print("===============")
        print("")
        print("Best p till now",bestP)
        print("")
# Out:
# === for 1 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0
# score difference {(newscore-bestScore)/newscore)} is 1.0  And current number of neighbours is 1
# New bestP: 0     and best K is:----> 1  New best score: 0.25
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.25
# score difference {(newscore-bestScore)/newscore)} is 0.5  And current number of neighbours is 2
# New bestP: 0     and best K is:----> 2  New best score: 0.5
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 2 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.5
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.5
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 3 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.5
# score difference {(newscore-bestScore)/newscore)} is 0.3333333333333333  And current number of neighbours is 1
# New bestP: 2     and best K is:----> 1  New best score: 0.75
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is -0.5  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 2
#
# === for 4 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is -0.5  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is -0.5  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 2
#
# === for 1 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0
# score difference {(newscore-bestScore)/newscore)} is 1.0  And current number of neighbours is 1
# New bestP: 0     and best K is:----> 1  New best score: 0.75
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is -0.5  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 2 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 3 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 4 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.75
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 1 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0
# score difference {(newscore-bestScore)/newscore)} is 1.0  And current number of neighbours is 1
# New bestP: 0     and best K is:----> 1  New best score: 0.3333333333333333
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.3333333333333333
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 2 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.3333333333333333
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.3333333333333333
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 0
#
# === for 3 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.3333333333333333
# score difference {(newscore-bestScore)/newscore)} is 0.0  And current number of neighbours is 1
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 0.3333333333333333
# score difference {(newscore-bestScore)/newscore)} is 0.5  And current number of neighbours is 2
# New bestP: 2     and best K is:----> 2  New best score: 0.6666666666666666
# -------End of this KNN loop-----
# ===============
#
# Best p till now 2
#
# === for 4 features:===
# ---- Performing KNN, 1 is the number of neighbours:----
# Best score untill now: 0.6666666666666666
# score difference {(newscore-bestScore)/newscore)} is 0.33333333333333337  And current number of neighbours is 1
# New bestP: 3     and best K is:----> 1  New best score: 1.0
# -------End of this KNN loop-----
# ---- Performing KNN, 2 is the number of neighbours:----
# Best score untill now: 1.0
# score difference {(newscore-bestScore)/newscore)} is -0.5000000000000001  And current number of neighbours is 2
# -------End of this KNN loop-----
# ===============
#
# Best p till now 3
